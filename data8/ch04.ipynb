# %%
42
# Out:
# 42

# %%
type(42)
# Out:
# int

# %%
type(42.5)
# Out:
# float

# %%
round(3.14159, 3)
# Out:
# 3.142

# %%
type(round)
# Out:
# builtin_function_or_method

# %%
1.5 + 2
# Out:
# 3.5

# %%
8 / 2
# Out:
# 4.0

# %%
x = 42
x * 2
# Out:
# 84

# %%
type(x)
# Out:
# int

# %%
x = 3.14
type(x)
# Out:
# float

# %%
5e6
# Out:
# 5000000.0

# %%
0.5555555555555555 - 0.5555555555555555123456789
# Out:
# 0.0

# %%
# floats are not perfectly perfectly precise - you only get ~16 decimal paces of "precision"

# %%
2 ** 1000 # ints are precise!
# Out:
# 

# %%
2 ** 0.5
# Out:
# 1.4142135623730951

# %%
(2 ** 0.5) * (2 ** 0.5)
# Out:
# 2.0000000000000004

# %%
type('hi mom')
# Out:
# str

# %%
type("Hello, world!")
# Out:
# str

# %%
'DATA' + " 8"
# Out:
# 'DATA 8'

# %%
'4' + '2'
# Out:
# '42'

# %%
'can't do this with ''s'
# Out:
#   Cell In[21], line 1
#     'can't do this with ''s'
#                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'can\'t do this with \'\'s'
# Out:
# "can't do this with ''s"

# %%
"can't do this with ''s"
# Out:
# "can't do this with ''s"

# %%
4 < 5
# Out:
# True

# %%
type(4 < 5)
# Out:
# bool

# %%
'the answer is: ' + (2 + 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 'the answer is: ' + (2 + 2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
str(2 + 2)
# Out:
# '4'

# %%
'the answer is: ' + str(2 + 2)
# Out:
# 'the answer is: 4'

# %%
'42' + '42'
# Out:
# '4242'

# %%
int('42') + int('42')
# Out:
# 84

# %%
int(2.5)
# Out:
# 2

# %%
float('forty-two')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 float('forty-two')
#
# ValueError: could not convert string to float: 'forty-two'

# %%
float('3.14')
# Out:
# 3.14

# %%
str('hello')
# Out:
# 'hello'

# %%
2 < 3
# Out:
# True

# %%
3 < 2
# Out:
# False

# %%
4 = 4
# Out:
#   Cell In[37], line 1
#     4 = 4
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
4 == 4
# Out:
# True

# %%
2 != 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
'hi' == 'hi'
# Out:
# True

# %%
'hi' < 'mom'
# Out:
# True

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # Miscellaneous things Lawton needs to teach you

# %%
'data 8'.upper()
# Out:
# 'DATA 8'

# %%
'hitchhiker'.replace('hi', 'ma')
# Out:
# 'matchmaker'

# %%
import math

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
round(3.14159, 2)
# Out:
# 3.14

# %%
math.floor(2.72)
# Out:
# 2

# %%
math.floor(2)
# Out:
# 2

# %%
math.ceil(3.14)
# Out:
# 4

# %%
'i can't do this'
# Out:
#   Cell In[55], line 1
#     'i can't do this'
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"can't"
# Out:
# "can't"

# %%
'can\'t'
# Out:
# "can't"

# %%
len('hello')
# Out:
# 5
